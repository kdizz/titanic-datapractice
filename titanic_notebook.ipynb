# %%
#load the requisite packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# The data set provided is for the passengers in the titanic, due to the nature of the

# %%
#loading the dataset and viewing the top
titan_df = pd.read_csv('titanic3.csv')
titan_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#to get info on the values in the data set
titan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
#to get summary statistics on the data.
titan_df.describe().round(3)
# Out:
#          pclass  survived       age     sibsp     parch      fare     body
# count  1309.000  1309.000  1046.000  1309.000  1309.000  1308.000  121.000
# mean      2.295     0.382    29.881     0.499     0.385    33.295  160.810
# std       0.838     0.486    14.413     1.042     0.866    51.759   97.697
# min       1.000     0.000     0.170     0.000     0.000     0.000    1.000
# 25%       2.000     0.000    21.000     0.000     0.000     7.896   72.000
# 50%       3.000     0.000    28.000     0.000     0.000    14.454  155.000
# 75%       3.000     1.000    39.000     1.000     0.000    31.275  256.000
# max       3.000     1.000    80.000     8.000     9.000   512.329  328.000

# %%
#to visualize the plot
sns.pairplot(titan_df)

# %%
#we will not get a correlation matrix of the data set because their is no causality to be determined.
#we need to create a new df less the string columns

# %%
titan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
#we shall visualize the fares distrivbution between men and women.
sns.histplot(data=titan_df, x='fare', bins = 10, palette='bright', hue = 'sex')
plt.title('Ticket fare distribution')
plt.ylabel('Number of tickets sold')
# Out:
# Text(0, 0.5, 'Number of tickets sold')

# %%
#to get the rpoportion of men and women on the boat
titan_df['sex'].value_counts()
#There were 843 men
#there were 466 women
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
#We shall find out which passengers had similar destinations.
destinations = titan_df['home.dest'].value_counts()
destinations.head(29)

# new york had the most residents onn the titanic
# Out:
# home.dest
# New York, NY                                 64
# London                                       14
# Montreal, PQ                                 10
# Paris, France                                 9
# Cornwall / Akron, OH                          9
# Wiltshire, England Niagara Falls, NY          8
# Winnipeg, MB                                  8
# Philadelphia, PA                              8
# Belfast                                       7
# Sweden Winnipeg, MN                           7
# Brooklyn, NY                                  7
# Ottawa, ON                                    5
# Rotherfield, Sussex, England Essex Co, MA     5
# Haverford, PA / Cooperstown, NY               5
# Sweden Worcester, MA                          5
# Somerset / Bernardsville, NJ                  5
# Bulgaria Chicago, IL                          5
# Syria New York, NY                            4
# Ruotsinphytaa, Finland New York, NY           4
# ...

# %%
nysex = titan_df[titan_df['home.dest'] == 'New York, NY']
nysex
# Out:
#      pclass  survived                                               name  \
# 5         1         1                                Anderson, Mr. Harry
# 10        1         0                             Astor, Col. John Jacob
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 15        1         0                                Baumann, Mr. John D
# 20        1         1                      Beckwith, Mr. Richard Leonard
# ..      ...       ...                                                ...
# 513       2         1                Nasser, Mrs. Nicholas (Adele Achem)
# 566       2         0                           Stanton, Mr. Samuel Ward
# 667       3         0                                 Barry, Miss. Julia
# 794       3         1                      Emanuel, Miss. Virginia Ethel
# 814       3         0                              Gallagher, Mr. Martin
#
#         sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
sns.histplot(data=nysex,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.violinplot(data=titan_df,)
# Out:
# <Axes: >

# %%
sns.histplot(data=titan_df,x='pclass', hue = 'sex')
#ask how to plot hue side by side rather than on the same line
# Out:
# <Axes: xlabel='pclass', ylabel='Count'>
